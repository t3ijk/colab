# %%
# https://huggingface.co/ehartford/samantha-7b?


# !git lfs install
# !git clone https://huggingface.co/TheBloke/samantha-13B-GGML
# Out:
# Error: Failed to call git rev-parse --git-dir: exit status 128
# Git LFS initialized.
# Cloning into 'samantha-13B-GGML'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 39 (delta 17), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (39/39), 6.53 KiB | 514.00 KiB/s, done.
# error: unable to write file samantha-13b.ggmlv3.q4_1.bin
