# %%
import torch
import random

torch.manual_seed(1)

# %%
a = [1, 2, 3 ,4, 5]


random.Random(1).shuffle(a)
random.Random(1).shuffle(a)

print(a)
# Out:
# [5, 1, 2, 3, 4]

# %%
# torch.get_rng_state().tolist()


print(torch.get_rng_state())

a =  torch.tensor(torch.get_rng_state().tolist(), dtype=torch.uint8).to(torch.device('cpu'))
torch.set_rng_state(a)
# Out:
# tensor([1, 0, 0,  ..., 0, 0, 0], dtype=torch.uint8)
