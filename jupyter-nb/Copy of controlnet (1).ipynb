# %%
# !git clone --recursive https://huggingface.co/spaces/hysts/ControlNet
# %cd ControlNet
# !git log
# Out:
# fatal: destination path 'ControlNet' already exists and is not an empty directory.
# /content/ControlNet/ControlNet/ControlNet
# commit f4748e3630d8141d7765e2bd9b1e348f47847707 (HEAD)
# Merge: 222a2a5 6552820
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Mon Feb 13 14:31:41 2023 -0800
#
#     Merge pull request #40 from eltociear/patch-1
#
#     Update README.md
#
# commit 222a2a5c03a28ea4329ababf8639b17f391e759a
# Merge: 330064d 2563cd5
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Mon Feb 13 14:30:16 2023 -0800
#
#     Merge pull request #25 from camenduru/cuda
#
#     please use vram
#
# commit 6552820e3760ff07cbbeca7d63276cf9eaa239c3
# Author: Ikko Eltociear Ashimine <eltociear@gmail.com>
# Date:   Tue Feb 14 03:20:22 2023 +0900
#
#     Update README.md
#
#     huggingface -> Hugging Face
#
# commit 330064db78c54b6a9710e883f1c885ffadc3f7c7
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sun Feb 12 16:30:32 2023 -0800
#
#     fix training image space
#
# commit 2563cd51314bf5212139a56f5706b5286ac766eb
# Author: camenduru <54370274+camenduru@users.noreply.github.com>
# Date:   Mon Feb 13 02:12:36 2023 +0300
#
#     cuda
#
# commit 6aac3be60c286cbd2427a059bbb5825e60380618
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sun Feb 12 11:20:28 2023 -0800
#
#     Update train.md
#
# commit 9f571d501f5fda99bfd6acf0ac74ba0eec7174aa
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sun Feb 12 11:18:32 2023 -0800
#
#     Update train.md
#
# commit ce1be6a6fce8050facbc9caeb55ec7aa5a6de6ac
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sun Feb 12 11:06:43 2023 -0800
#
#     i
#
# commit 441d344df4a8262d0a4123848bf48ba88725f101
# Merge: aaae601 3933672
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sun Feb 12 11:04:46 2023 -0800
#
#     Merge pull request #20 from scarbain/feature/random_seed
#
#     Allow setting -1 as seed for random
#
# commit 3933672c28ca7ee9b259c48886bdef949f86df9e
# Author: scarbain <sebastien.carbain@gmail.com>
# Date:   Sun Feb 12 19:54:36 2023 +0100
#
#     Allow setting -1 as seed for random
#
# commit aaae601ba0cc4c4878a2f32916834bca020e6488
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sun Feb 12 10:50:45 2023 -0800
#
#     i
#
# commit a318b45b28c49439545f1a58ed3d626c2c6203e5
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sun Feb 12 10:49:57 2023 -0800
#
#     i
#
# commit f39054af960f8284b0c9cf29fe08d4492a525ca5
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sun Feb 12 10:34:12 2023 -0800
#
#     negative fix
#
# commit 127b8ffa37277eec36e50c4c9bf51772638da8c6
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sun Feb 12 10:33:05 2023 -0800
#
#     negative fix
#
# commit eedb26e532a6ec07f4dad7018b8df1d6047016c6
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sun Feb 12 10:14:37 2023 -0800
#
#     Update low_vram.md
#
# commit e9ba9af29fdae615b5131884340c4b4a704a924a
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 23:10:01 2023 -0800
#
#     Update README.md
#
# commit 0fe2acec3e93a5a18e6256f8960082bf70696708
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 23:09:11 2023 -0800
#
#     Update README.md
#
# commit 2029ae2ba68990b0d33bbf8bbfb00f680d7ff920
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 23:04:48 2023 -0800
#
#     Update README.md
#
# commit cf6480a18574f79a18e7066b063af2e101ac5dac
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 22:04:59 2023 -0800
#
#     i
#
# commit 1df02f2b936ddaa06e145b606edd72861dffd636
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 21:35:10 2023 -0800
#
#     i
#
# commit d7e10000968b60abe1ed77110360048e3ae43162
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 21:29:10 2023 -0800
#
#     i
#
# commit e0793b33a5b2fd1fae15ba65ff44139669520158
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 21:18:27 2023 -0800
#
#     i
#
# commit 126ed386d459b581a15bf742c02152ec44c048db
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 21:10:32 2023 -0800
#
#     cpu safe tensor fix
#
# commit 9224e65d6557d061b320765dc922197c1a935354
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 21:05:26 2023 -0800
#
#     i
#
# commit 017a6e950e38e7e45c89fae96f80ebab81dc3ede
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 20:41:56 2023 -0800
#
#     safetensor
#
# commit e94575d62e30740b022cd77ec54bd1bea7c1edf3
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 19:04:11 2023 -0800
#
#     safetensor
#
# commit dd715abec13da130c940e8a2375af76ef9989394
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 18:13:36 2023 -0800
#
#     Update low_vram.md
#
# commit 54de9e9657bb9f7e722a5d1d6389207635b60284
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 16:42:36 2023 -0800
#
#     Update low_vram.md
#
# commit 99cde25ec761d239030678146c464dd875a0d0f9
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 16:24:39 2023 -0800
#
#     i
#
# commit b6aece3edfc819dee1c345ae84120b21ae1c4a80
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 16:21:23 2023 -0800
#
#     Update README.md
#
# commit 6cf56ec5460a74d693a2af167e1b6bf06f56949c
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 16:16:48 2023 -0800
#
#     i
#
# commit 87ca0d2baa91e41109bdcb0b36ff86d674b3134c
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 16:13:16 2023 -0800
#
#     i
#
# commit edca5b1b36a6e1622f233ad38899d7ecd46e9f3d
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 16:09:31 2023 -0800
#
#     i
#
# commit df9344541dad862a862a31d89577a0c3c3008d78
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 16:09:02 2023 -0800
#
#     i
#
# commit dbb1ca22d83221c23167bb78d65feaf1da7b9bd8
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 16:07:47 2023 -0800
#
#     i
#
# commit ec6734e5de98948d63bb0cf379372cb7748ee327
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 15:44:27 2023 -0800
#
#     i
#
# commit 1e5c75a5cfb45c3fc727a152238045fb51f5660a
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 15:40:33 2023 -0800
#
#     low_vram
#
# commit 5be9c5e02c8356b2f963efd1531d44a2a759a148
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 14:51:07 2023 -0800
#
#     i
#
# commit 358ded39ed64ebf5031e3e671da24b6a3945a028
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 14:47:24 2023 -0800
#
#     i
#
# commit 1838f1ffd9b4806e1bba651cd9cb4d2ca9c6a0c5
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 14:31:46 2023 -0800
#
#     Update train.md
#
# commit a59712048ddbba7b07dc5fa907dd2cf86d42ed8b
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 07:06:59 2023 -0800
#
#     Update README.md
#
# commit d617a48c279dca51b39e86304f7892ca7c88e765
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Sat Feb 11 06:33:53 2023 -0800
#
#     Update README.md
#
# commit 1926b7144e69b4cc7542437bbcb1643c878094d9
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 23:30:38 2023 -0800
#
#     i
#
# commit 0d8127cc251bbb47457705bc02ecd01da77179fe
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 23:29:25 2023 -0800
#
#     i
#
# commit 11718f9672e9d91fcb3dd9a0b5d5a31b1144b207
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 23:22:49 2023 -0800
#
#     Update train.md
#
# commit 1043b5891d33f65c584eedb95486e69ce1c47d42
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 23:22:19 2023 -0800
#
#     Update train.md
#
# commit 3771315f284e25af597efc46d9dfb8dd5cb4aa2f
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 23:18:29 2023 -0800
#
#     Update train.md
#
# commit ef8e2596393c1917660104ab0bbe13ff0642f2d4
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 18:58:49 2023 -0800
#
#     Update FAQ.md
#
# commit 6e9b5037a8a9d8af7d33f7b7a8a59420ad0f0cfb
# Author: lllyasviel <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 18:58:18 2023 -0800
#
#     Update README.md
#
# commit fb059ea8c9fba24991f3fdd6124321026f851fc7
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 17:51:05 2023 -0800
#
#     i
#
# commit 142cac4867b7c7efdc4d8fd9f36a618e29c03135
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 17:50:16 2023 -0800
#
#     i
#
# commit a6033012e87343f05e1452cecb6b3635fc1064c6
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 15:39:42 2023 -0800
#
#     i
#
# commit af9996e6f393ba54b49abbf46dc90ab48b99c307
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 15:39:05 2023 -0800
#
#     i
#
# commit 6c7704eb525b30a57fb07a14c7b4905ee5b9e16e
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 15:09:33 2023 -0800
#
#     i
#
# commit 88c94181314070ac3179f7887500ad45a3b62357
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 15:03:47 2023 -0800
#
#     i
#
# commit 18ad9ad68ad17905374b09e9a83b85d2082ffb9f
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 15:03:04 2023 -0800
#
#     i
#
# commit 9dfb86df1e8d81a69acf8c71303018f41e51c0de
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 15:00:55 2023 -0800
#
#     i
#
# commit d614f2cddd000c42a1e4c12095a696812a930c5c
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 14:59:40 2023 -0800
#
#     i
#
# commit f2f36e1876ffb31537818938f997c0a2d866ce74
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 14:57:49 2023 -0800
#
#     i
#
# commit 978ba0798b28c142161413cc5907b55f58dc2375
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 14:56:58 2023 -0800
#
#     i
#
# commit db2f33494a384f2c380db34f222729ffb96b2955
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 11:30:43 2023 -0800
#
#     i
#
# commit e38d22aa1ce2c2c72d2536c8f337b47249033c98
# Author: lvmin <lyuminzhang@outlook.com>
# Date:   Fri Feb 10 11:28:11 2023 -0800
#
#     i

# %%
# %cd ControlNet
# Out:
# /content/ControlNet/ControlNet

# %%
# Out:
# app_canny.py          app.py*                      model.py
# app_depth.py          app_scribble_interactive.py  notebooks/
# app_fake_scribble.py  app_scribble.py              patch
# app_hed.py            app_seg.py                   README.md
# app_hough.py          ControlNet/                  requirements.txt
# app_normal.py         LICENSE                      style.css
# app_pose.py           LICENSE.ControlNet

# %%
# !pip install -q -r requirements.txt
# !cd ControlNet && git apply ../patch
# !sed -i '150d' app.py
# !sed -i "149a demo.queue(api_open=False).launch(share=True, file_directories=['/tmp'])" app.py
# !python app.py

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-e90b3640d5d3> in <module>
# ----> 1 from moviepy.editor import *
#
# /usr/local/lib/python3.9/dist-packages/moviepy/editor.py in <module>
#      24 # Checks to see if the user has set a place for their own version of ffmpeg
#      25 if os.getenv('FFMPEG_BINARY', 'ffmpeg-imageio') == 'ffmpeg-imageio':
# ---> 26     imageio.plugins.ffmpeg.download()
#      27
#      28 # Clips
#
# /usr/local/lib/python3.9/dist-packages/imageio/plugins/ffmpeg.py in download(directory, force_download)
#     161
#     162 def download(directory=None, force_download=False):  # pragma: no cover
# --> 163     raise RuntimeError(
#     164         "imageio.ffmpeg.download() has been deprecated. "
#     165         "Use 'pip install imageio-ffmpeg' instead.'"
#
# RuntimeError: imageio.ffmpeg.download() has been deprecated. Use 'pip install imageio-ffmpeg' instead.'
